# %%
GPU_NUM=1
CGF="./config/cfg_odvg.py"
DATASETS="./config/datasets_mixed_odvg.json"
OUTPUT_DIR="./output"
# !chmod +x train_dist.sh
# !bash train_dist.sh {CGF} {DATASETS} {OUTPUT_DIR}
# Out:
# Not using distributed mode
# Loading config file from ./config/cfg_odvg.py
# INFO     2025-02-05 17:03:27,669 | git:
#   sha: 3554673dfcec07450c16f770a2f05479f764a638, status: has uncommited changes, branch: main
#
# INFO     2025-02-05 17:03:27,677 | Command: main.py --config_file ./config/cfg_odvg.py --datasets ./config/datasets_mixed_odvg.json --output_dir ./output --pretrain_model_path ./groundingdino_swint_ogc.pth --options text_encoder_type=./bert
# INFO     2025-02-05 17:03:27,774 | Full config saved to ./output/config_args_all.json
# INFO     2025-02-05 17:03:27,807 | world size: 1
# INFO     2025-02-05 17:03:27,812 | rank: 0
# INFO     2025-02-05 17:03:27,817 | local_rank: 0
# ...

# %%
# !bash train_dist.sh "./config/cfg_odvg.py" "./config/datasets_mixed_odvg.json" "./output"
